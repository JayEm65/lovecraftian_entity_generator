# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import os
import random
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Create a data directory if it doesn't exist
os.makedirs('data', exist_ok=True)

# Set up retries for failed requests
session = requests.Session()
retries = Retry(total=3, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
session.mount('http://', HTTPAdapter(max_retries=retries))
session.mount('https://', HTTPAdapter(max_retries=retries))

def scrape_lovecraft_content(content_type):
    """
    Scrapes H.P. Lovecraft's writings based on the content type specified (fiction, poetry, essays, letters).
    
    Parameters:
        content_type (str): The type of content to scrape ('fiction', 'poetry', 'essays', 'letters').
    """
    # Base URL
    base_url = "https://www.hplovecraft.com/writings/texts/"
    response = session.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        content_links = []

        # Find all relevant links
        for link in soup.find_all('a', href=True):
            href = link['href']
            if href.startswith(f'{content_type}/') and not href.startswith('#'):
                full_url = f"{base_url}{href}"
                content_links.append(full_url)

        # Open CSV file to write
        csv_filename = f'data/lovecraft_{content_type}.csv'
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            csvwriter = csv.writer(csvfile)
            csvwriter.writerow(['Content Type', 'Title', 'Text'])  # Add content type column

            for content_url in content_links:
                time.sleep(random.uniform(1, 3))  # Randomize throttle time between 1-3 seconds
                try:
                    headers = {'User-Agent': 'Mozilla/5.0'}
                    content_response = session.get(content_url, headers=headers)

                    if content_response.status_code == 200:
                        content_soup = BeautifulSoup(content_response.content, 'html.parser')
                        title_tag = content_soup.find('font', size="+2")  # Title font size
                        author_tag = content_soup.find('font', size="+1")  # Author font size
                        text_div = content_soup.find('div', align='justify')  # Update as necessary

                        # Validate title and text
                        if title_tag and text_div:
                            title = f"{title_tag.get_text(strip=True)} by {author_tag.get_text(strip=True)}"
                            csvwriter.writerow([content_type, title, text_div.get_text(strip=True)])
                            print(f'Scraped: {title}')
                        else:
                            print(f'Title or text not found for {content_url}')
                    else:
                        print(f'Failed to scrape {content_url}: {content_response.status_code}')
                except Exception as e:
                    print(f'Error scraping {content_url}: {e}')
    else:
        print(f'Failed to access the base URL: {response.status_code}')

# Scrape different types of content
for content in ['fiction', 'poetry', 'essays', 'letters']:
    scrape_lovecraft_content(content)
# Out:
# Scraped: The AlchemistBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: AshesBy C. M. Eddy, Jr.with H. P. Lovecraft by By C. M. Eddy, Jr.with H. P. Lovecraft
# Scraped: At the Mountains of MadnessBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: AzathothBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Battle that Ended the Century(MS. Found in a Time Machine)By R. H. Barlowwith H. P. Lovecraft by (MS. Found in a Time Machine)By R. H. Barlowwith H. P. Lovecraft
# Scraped: The Beast in the CaveBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Beyond the Wall of SleepBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The BookBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Call of CthulhuBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Case of Charles Dexter WardBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Cats of UltharBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: CelephaïsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Challenge from BeyondBy C.L. Moore, A. Merritt, H.P. Lovecraft,Robert E. Howard, and Frank Belknap Long by By C.L. Moore, A. Merritt, H.P. Lovecraft,Robert E. Howard, and Frank Belknap Long
# Scraped: Collapsing CosmosesBy R. H. Barlowand H. P. Lovecraft by By R. H. Barlowand H. P. Lovecraft
# Scraped: The Colour out of SpaceBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Cool AirBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Crawling ChaosBy H. P. Lovecraftwith Winifred V. Jackson by By H. P. Lovecraftwith Winifred V. Jackson
# Scraped: The Curse of YigBy H. P. Lovecraftfor Zealia Bishop by By H. P. Lovecraftfor Zealia Bishop
# Scraped: DagonBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Deaf, Dumb, and BlindBy C. M. Eddy, Jr.and H. P. Lovecraft by By C. M. Eddy, Jr.and H. P. Lovecraft
# Scraped: The DescendantBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Diary of Alonzo TyperBy H. P. Lovecraftfor William Lumley by By H. P. Lovecraftfor William Lumley
# Scraped: The DisintermentBy Duane W. Rimeland H. P. Lovecraft by By Duane W. Rimeland H. P. Lovecraft
# Scraped: The Doom That Came to SarnathBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Dream-Quest of Unknown KadathBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Dreams in the Witch HouseBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Dunwich HorrorBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Electric ExecutionerBy H. P. Lovecraftwith Adolphe de Castro by By H. P. Lovecraftwith Adolphe de Castro
# Scraped: The Evil ClergymanBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Ex OblivioneBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Facts concerning the LateArthur Jermyn and His FamilyBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The FestivalBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: From BeyondBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Ghost-EaterBy C. M. Eddy, Jr.with H. P. Lovecraft by By C. M. Eddy, Jr.with H. P. Lovecraft
# Scraped: The Green MeadowBy H. P. Lovecraftand Winifred V. Jackson by By H. P. Lovecraftand Winifred V. Jackson
# Scraped: The Haunter of the DarkBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: HeBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Herbert West—ReanimatorBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: History of the NecronomiconBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Hoard of the Wizard-BeastBy R. H. Barlowand H. P. Lovecraft by By R. H. Barlowand H. P. Lovecraft
# Scraped: The Horror at Martin’s BeachBy H. P. Lovecraftand Sonia H. Greene by By H. P. Lovecraftand Sonia H. Greene
# Scraped: The Horror at Red HookBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Horror in the Burying-GroundBy H. P. Lovecraftfor Hazel Heald by By H. P. Lovecraftfor Hazel Heald
# Scraped: The Horror in the MuseumBy H. P. Lovecraftfor Hazel Heald by By H. P. Lovecraftfor Hazel Heald
# Scraped: The HoundBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: HypnosBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: IbidBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: In the VaultBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: In the Walls of EryxBy H. P. Lovecraftwith Kenneth Sterling by By H. P. Lovecraftwith Kenneth Sterling
# Scraped: The Last TestBy H. P. Lovecraftwith Adolphe de Castro by By H. P. Lovecraftwith Adolphe de Castro
# Scraped: The Little Glass BottleBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Loved DeadBy C. M. Eddy, Jr.and H. P. Lovecraft by By C. M. Eddy, Jr.and H. P. Lovecraft
# Scraped: The Lurking FearBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Man of StoneBy Hazel Healdwith H. P. Lovecraft by By Hazel Healdwith H. P. Lovecraft
# Scraped: Medusa’s CoilBy H. P. Lovecraftfor Zealia Bishop by By H. P. Lovecraftfor Zealia Bishop
# Scraped: MemoryBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Moon-BogBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The MoundBy H. P. Lovecraftfor Zealia Bishop by By H. P. Lovecraftfor Zealia Bishop
# Scraped: The Music of Erich ZannBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Mysterious ShipBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Mystery of the Grave-Yardor “A Dead Man’s Revenge”A Detective Story,by H. P. Lovecraft by A Detective Story,by H. P. Lovecraft
# Scraped: The Nameless CityBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Night OceanBy R. H. Barlowwith H. P. Lovecraft by By R. H. Barlowwith H. P. Lovecraft
# Scraped: NyarlathotepBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Old BugsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Other GodsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Out of the AeonsBy H. P. Lovecraftfor Hazel Heald by By H. P. Lovecraftfor Hazel Heald
# Scraped: The OutsiderBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Pickman’s ModelBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Picture in the HouseBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Poetry and the GodsBy H. P. Lovecraftand Anna Helen Crofts by By H. P. Lovecraftand Anna Helen Crofts
# Scraped: PolarisBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Quest of IranonBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Rats in the WallsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: A Reminiscence of Dr. Samuel JohnsonBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Secret Caveor John Lees adventureBy H. P. Lovecraft by or John Lees adventureBy H. P. Lovecraft
# Scraped: The Shadow out of TimeBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Shadow over InnsmouthBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Discarded Draft of“The Shadow over Innsmouth”By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Shunned HouseBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Silver KeyBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Slaying of the MonsterBy R. H. Barlowand H. P. Lovecraft by By R. H. Barlowand H. P. Lovecraft
# Scraped: The Statement of Randolph CarterBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Strange High House in the MistBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The StreetBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Sweet ErmengardeOr, the Heart of a Country GirlBy Percy Simple [H. P. Lovecraft] by Or, the Heart of a Country GirlBy Percy Simple [H. P. Lovecraft]
# Scraped: The TempleBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Terrible Old ManBy H. P. Lovecraft by By H. P. Lovecraft
# Error scraping https://www.hplovecraft.com/writings/texts/fiction/tm.aspx: 'NoneType' object has no attribute 'get_text'
# Scraped: The Thing on the DoorstepBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Through the Gates of the Silver KeyBy H. P. Lovecraftand E. Hoffmann Price by By H. P. Lovecraftand E. Hoffmann Price
# Scraped: “Till A’ the Seas”By R. H. Barlowand H. P. Lovecraft by By R. H. Barlowand H. P. Lovecraft
# Scraped: The TombBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Transition of Juan RomeroBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The TrapBy H. P. Lovecraftwith Henry S. Whitehead by By H. P. Lovecraftwith Henry S. Whitehead
# Scraped: The TreeBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Tree on the HillBy Duane W. Rimeland H. P. Lovecraft by By Duane W. Rimeland H. P. Lovecraft
# Scraped: Two Black BottlesBy Wilfred Blanch Talmanwith H. P. Lovecraft by By Wilfred Blanch Talmanwith H. P. Lovecraft
# Scraped: Under the PyramidsBy H. P. Lovecraftfor Harry Houdini by By H. P. Lovecraftfor Harry Houdini
# Scraped: The UnnamableBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Very Old FolkBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: What the Moon BringsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Whisperer in DarknessBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The White ShipBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Winged DeathBy H. P. Lovecraftwith Hazel Heald by By H. P. Lovecraftwith Hazel Heald
# Scraped: An American to Mother EnglandBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Ancient TrackBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: ArcadiaBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: AstrophobosBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The CatsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: ChristmasBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetingsto Annie E. P. Gamwell]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetingsto Eugene B. Kuntz et al.]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetings to Felis(Frank Belknap Long’s cat)]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetings to Felis(Frank Belknap Long’s cat)]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetings to Laurie A. Sawyer]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetings to Rheinhart Kleiner]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: [Christmas Greetings to Sonia H. Greene]By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The CityBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The ConscriptBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Dead Passion’s FlameBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: DespairBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Fact and FancyBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: FestivalBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Fungi from YuggothBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: A GardenBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Hallowe’en in a SuburbBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The HouseBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: In a Sequester’d Providence ChurchyardWhere Once Poe Walk’dBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Laeta; a LamentBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Life’s MysteryBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Lines on Gen. Robert Edward LeeBorn Jan. 19, 1807By H. P. Lovecraft by Born Jan. 19, 1807By H. P. Lovecraft
# Scraped: The MessengerBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: NathicanaBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: NemesisBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Nightmare LakeBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Ode for July Fourth, 1917By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: On Reading Lord Dunsany’sBook of WonderBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: On Receiving a Picture of SwansBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The OutpostBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Pacifist War Song—1917By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Peace AdvocateBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Poe-et’s NightmareBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Poemata Minora, Volume IIBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: ProvidenceBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Psychopompos: A Tale in RhymeBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: RevelationBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Rose of EnglandBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: SunsetBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: To Clark Ashton Smith, Esq.,upon His Phantastick Tales,Verses, Pictures, and SculpturesBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: To Edward John Moreton Drax Plunkett,Eighteenth Baron DunsanyBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Unda; or, The Bride of the SeaBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Waste PaperA Poem of Profound InsignificanceBy H. P. Lovecraft by A Poem of Profound InsignificanceBy H. P. Lovecraft
# Scraped: The WoodBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Allowable RhymeBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: At the RootBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Cats and DogsBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: The Despised PastoralBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Literary CompositionBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Metrical RegularityBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Notes on Writing Weird FictionBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Supernatural Horror in LiteratureBy H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Letter to the Gallomo(Alfred Galpin, Samuel Loveman,and Maurice W. Moe),11 December 1919By H. P. Lovecraft by By H. P. Lovecraft
# Scraped: Letter to Clark Ashton Smith,27 November 1927By H. P. Lovecraft by By H. P. Lovecraft
